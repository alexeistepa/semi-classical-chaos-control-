# %%
import fSRK_testros as ros
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
print(ros.__doc__)
# Out:
# This module 'fSRK_testros' is auto-generated with f2py (version:2).
# Functions:
#   f = test1_drf(t,r,pr,n=len(r),np=len(pr))
#   g = test1_dif(t,r,pr,n=len(r),np=len(pr))
#   f = drift(t,r,p,n=len(r),np=len(p))
#   g = diffus(t,r,p,n=len(r),np=len(p))
#   rout,tout = fsrkstp(r0,t0,delt,nstp,p,n=len(r0),np=len(p))
#   rvals,tvals = fsrk(r0,t0,tf,nout,nps,p,n=len(r0),np=len(p))
#   normal = normal()
# .

# %%
r0 = np.array([1,0,0])
p = np.array([0.2,0.2,5.7,0.2,2])
t0 = 0
tf = 5000
nout = 500000
nps = 5

# %%
vals = ros.fsrk(r0,t0,tf,nout,nps,p)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(vals[0][0],vals[0][1],vals[0][2], linewidth = 0.05)
fig.set_size_inches(9, 7) 

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
